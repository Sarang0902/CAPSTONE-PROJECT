# %% [markdown]
# Dear Participant,
#
# Parkinson’s Disease (PD) is a degenerative neurological disorder marked by decreased dopamine levels in the brain. It manifests itself through a deterioration of movement, including the presence of tremors and stiffness. There is commonly a marked effect on speech, including dysarthria (difficulty articulating sounds), hypophonia (lowered volume), and monotone (reduced pitch range). Additionally, cognitive impairments and changes in mood can occur, and risk of dementia is increased.
#
# Traditional diagnosis of Parkinson’s Disease involves a clinician taking a neurological history of the patient and observing motor skills in various situations. Since there is no definitive laboratory test to diagnose PD, diagnosis is often difficult, particularly in the early stages when motor effects are not yet severe. Monitoring progression of the disease over time requires repeated clinic visits by the patient. An effective screening process, particularly one that doesn’t require a clinic visit, would be beneficial. Since PD patients exhibit characteristic vocal features, voice recordings are a useful and non-invasive tool for diagnosis. If machine learning algorithms could be applied to a voice recording dataset to accurately diagnosis PD, this would be an effective screening step prior to an appointment with a clinician.
#
# Use the provided dataset in order to do your analysis.

# %% [markdown]
# #Attribute Information:
#
# #Matrix column entries (attributes):
# #name - ASCII subject name and recording number
# #MDVP:Fo(Hz) - Average vocal fundamental frequency
# #MDVP:Fhi(Hz) - Maximum vocal fundamental frequency
# #MDVP:Flo(Hz) - Minimum vocal fundamental frequency
# #MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP - Several
# #measures of variation in fundamental frequency
# #MDVP:Shimmer,MDVP:Shimmer(dB),Shimmer:APQ3,Shimmer:APQ5,MDVP:APQ,Shimmer:DDA - Several measures of variation in amplitude
# #NHR,HNR - Two measures of ratio of noise to tonal components in the voice
# #status - Health status of the subject (one) - Parkinson's, (zero) - healthy
# #RPDE,D2 - Two nonlinear dynamical complexity measures
# #DFA - Signal fractal scaling exponent
# #spread1,spread2,PPE - Three nonlinear measures of fundamental frequency variation

# %%
# Import required library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Q1. Load the dataset

# %%
parkinson_data=pd.read_csv('parkinsons.csv')
parkinson_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinson_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
parkinson_data.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %% [markdown]
# ### Q2. Use the .describe() method on the dataset and state any insights you may come across.

# %%
parkinson_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %% [markdown]
# ### Q3. Check for class imbalance. Do people with Parkinson's have greater representation in the dataset?

# %%
parkinson_data['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %% [markdown]
# **Interpretation:** Yes, in this dataset people with parkinson disease than the healthy ones.

# %% [markdown]
# ### Q4. Check for missing vaues and take necessary measures by dropping observation or imputing them.

# %%
parkinson_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# ### Q5. Plot the distribution of all the features. State any observations you can make based on the distribution plots.

# %%
plt.rcParams['figure.figsize']=(17,15)
parkinson_data.hist()
plt.show()

# %% [markdown]
# ### Q6. Check for outliers in the data. Are there any variables with high amount of outliers.

# %%
import numpy as np
plt.rcParams['figure.figsize']=(10,8)
for i in parkinson_data.select_dtypes(include=np.number):
    sns.boxplot(parkinson_data[i])
    plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# **Interpretation:** Among all the variables,NHR is having most of the outliers and showing positive skewness.

# %%
parkinson_data.drop('name',axis=1,inplace=True)

# %%
q1=parkinson_data.quantile(0.25)
q3=parkinson_data.quantile(0.75)
IQR=q3-q1
parkinson_data=parkinson_data[~((parkinson_data<(q1-1.5*IQR))|(parkinson_data>(q3+1.5*IQR))).any(axis=1)]
parkinson_data.shape
# Out:
# (114, 23)

# %%
from sklearn.preprocessing import StandardScaler 
s_scale=StandardScaler()
X_feature=parkinson_data.drop('status',axis=1)
X = s_scale.fit_transform(X_feature)
y=parkinson_data['status']
X = pd.DataFrame(X, columns = X_feature.columns)

X.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0    -0.703290     -0.240244     -0.979039        1.210967          1.509410
# 1    -0.805728     -0.690575      0.179290        2.235985          2.527592
# 2    -0.694795     -0.705106      0.289298       -0.959377         -0.526954
# 3    -1.094384     -1.247515     -0.045280       -1.166305         -0.526954
# 4    -1.452794     -0.825064     -0.445340        0.089703          1.000319
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0  0.744022  2.191055    0.741604      1.355291          1.508393  ...
# 1  1.808994  3.404972    1.807202      2.276350          2.298539  ...
# 2 -0.990590 -0.776298   -0.988648     -0.923466         -0.974926  ...
# 3 -1.079338 -0.944897   -1.082830     -0.957243         -1.027023  ...
# 4  0.122789  0.319600    0.125387     -0.523901         -0.532096  ...
#
# ...

# %% [markdown]
# ### Q7. Are there any strong correlations among the independent features?

# %%
X.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.772636      0.364821       -0.244673
# MDVP:Fhi(Hz)         0.772636      1.000000      0.126676       -0.077533
# MDVP:Flo(Hz)         0.364821      0.126676      1.000000       -0.413651
# MDVP:Jitter(%)      -0.244673     -0.077533     -0.413651        1.000000
# MDVP:Jitter(Abs)    -0.606360     -0.375582     -0.449061        0.883929
# MDVP:RAP            -0.189027     -0.099526     -0.371567        0.966021
# MDVP:PPQ            -0.316729     -0.124401     -0.345370        0.949840
# Jitter:DDP          -0.189003     -0.099578     -0.371371        0.966027
# MDVP:Shimmer        -0.183530     -0.109878     -0.303665        0.506028
# MDVP:Shimmer(dB)    -0.209651     -0.111984     -0.333527        0.544039
# Shimmer:APQ3        -0.171951     -0.114970     -0.288308        0.502209
# Shimmer:APQ5        -0.168374     -0.093782     -0.252269        0.460368
# ...

# %% [markdown]
# **Interpretation:** There is no strong correlation between the indepandent variables.

# %% [markdown]
# ### Q8. Split dataset into training & test dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 10, test_size = 0.3)
print(X_train.shape,
      X_test.shape,
      y_train.shape,
      y_test.shape )
# Out:
# (79, 22) (35, 22) (79,) (35,)

# %% [markdown]
# ### Q9. Create a default decision tree model using criterion = Entropy

# %%
decision_tree_classification=DecisionTreeClassifier(criterion='entropy',random_state=10)
decision_tree=decision_tree_classification.fit(X_train,y_train)

# %% [markdown]
# ### Q10.  Use regularization parameters of max_depth, min_sample_leaf to recreate the model. What is the impact on the model accuracy? How does regularization help?

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
decision_tree_classification=DecisionTreeClassifier(criterion='entropy',max_depth = 5, min_samples_split = 4,max_leaf_nodes = 6,random_state=10)
decision_tree=decision_tree_classification.fit(X_train,y_train)

# %%
plt.figure(figsize=(10,8))
tree.plot_tree(decision_tree,feature_names=X_train.columns,class_names=['0','1'])
plt.show()

# %% [markdown]
# ### Q11. Implement a Random Forest model. What is the optimal number of trees that gives the best result?
